# %%
import pandas as pd

excel_file = '/Users/lionheart/Desktop/Martial-Arts-Training/WingChun.xls'

MA1 = pd.read_excel(excel_file, sheet_name=0)
MA2 = pd.read_excel(excel_file, sheet_name=1)
MA3 = pd.read_excel(excel_file, sheet_name=2)
MA4 = pd.read_excel(excel_file, sheet_name=3)
MA5 = pd.read_excel(excel_file, sheet_name=4)
MA6 = pd.read_excel(excel_file, sheet_name=5)

WingChun = pd.concat([MA1, MA2, MA3, MA4, MA5, MA6],keys=['Shadow Crescent','Wing Chun KO','Dragonblade','Blood Rain','Stretches','Boxing Combinations'], names=['Title'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(WingChun.fillna(''))
    WingChun.fillna('').to_csv(r'C:\Users\lionheart\Desktop\export_dataframe.csv', index = False, header=True)
# Out:
#                                                     Exercises Muscle Groups  \
# Title
# Shadow Crescent     0
#                     1                     Downward side kick
#                     2                  Reverse front crescent
#                     3                 Medium Front Roundhouse
#                     4                  Reverse front straight
#                     5
#                     6                       Leaping side kick
#                     7                        Upward side kick
#                     8                     Spinning back kick
#                     9                      (launch rear foot)
#                     10
#                     11                       Switch to boxing
#                     12
#                     13                         Straight leads
#                     14                          straight rear
#                     15                           Reverse lead
# ...
