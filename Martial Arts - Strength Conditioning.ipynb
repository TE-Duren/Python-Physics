# %%
import pandas as pd

excel_file = '/Users/lionheart/Desktop/Martial-Arts-Training/StrCond.xls'

MA = pd.read_excel(excel_file, sheet_name=0)
MA1 = pd.read_excel(excel_file, sheet_name=1)
MA2 = pd.read_excel(excel_file, sheet_name=2)

StrCond = pd.concat([MA,MA1,MA2], keys=['Rounded','Power Raiser','Ring the Bell'], names=['Title'],copy=False)
StrCond.fillna('')
# Out:
#                                                           Exercises  \
# Title
# Rounded       0                                     Incline Push-up
#               1                                     Decline Push-Up
#               2                                       Leg Lift Hold
#               3
#               4                                          3-mile Run
#               5
#               6                                  Water break, 5 min
#               7                                            Cyclical
#               8                                      Spade Pull-Ups
#               9                                Squats (Free weight)
#               10                                            Burpees
#               11
#               12                                        2 min break
#               13                                        Wrist Curls
#               14                                    Head/Neck Curls
# ...
