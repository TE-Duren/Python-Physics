# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .05e-3 #m
d = .5e-3
xlambda = 633e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .05e-3
d = .25e-3
xlambda = 633e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .025e-3
d = .5e-3
xlambda = 633e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .025e-3
d = .25e-3
xlambda = 6.33E-7

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .05e-3
d = .1e-3
xlambda = 400e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .05e-3
d = .5e-3
xlambda = 400e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.5f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
# %matplotlib inline
"""
This will plot double slit interference 
"""

""" Set up initial values of a (slit width), d (distance between slits), and wavelength"""
a = .025e-3
d = .5e-3
xlambda = 400e-9

I_0 = 1.0
"""Make a linear space spanning -0.05 to .05 radians"""
theta=np.linspace(-.15,.15,1001)
"""define angular quantities beta and phi and plug into intensity formula 
(See, e.g.,  Young and Freedman, Vol 13, pg 1200)

numpy is needed to define pi, sin, cos, and sinc"""
beta= 2.0*np.pi*a/xlambda*np.sin(theta)
#print (beta)
phi = 2.0*np.pi*d/xlambda*np.sin(theta)
Intensity = I_0*(np.cos(phi/2.0)**2*(np.sinc(beta/2))**2) 
#print(Intensity)
plt.plot(theta,Intensity)
plt.axis([-.05,.05,0,1.8])
plt.text(-.04, 1.2, r'$d = $%1.4f m   $a = $%1.6f  m  $\lambda = $%1.8f  m ' %(d,a, xlambda)  )
plt.text(-.04, 1.6, r'$I(\theta)=I_0 (\cos^2(\phi/2))^2[\sinc(\beta/2)]$', fontsize=15)
plt.text(-.04, 1.4, r'$\phi=2\pi d \sin(\theta)/\lambda$', fontsize=15)
plt.text(0, 1.4, r'$\beta= 2\pi a \sin(\theta)/\lambda$', fontsize = 15)
plt.show()
